# %%
# %cd /content/drive/My Drive/Colab Notebooks/deep-learning-from-scratch
# Out:
# /content/drive/My Drive/Colab Notebooks/deep-learning-from-scratch

# %%
# %rm .git -rf

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/Colab Notebooks/deep-learning-from-scratch/.git/

# %%
# !git add -A

# %%
# !git config --global user.email "miya.ryj@gmail.com"
# !git config --global user.name "miyaryj"

# %%
# !git commit --amend
# Out:
# hint: Waiting for your editor to close the file... error: unable to start editor 'editor'
# Please supply the message using either -m or -F option.

# %%
# !git remote add origin git@github.com:miyaryj/deep-learning-from-scratch.git

# %%
# !git remote set-url origin https://miyaryj:password@github.com/reponame.git

# %%
# !git push -u origin master
# Out:
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.
